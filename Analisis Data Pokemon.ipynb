# %%
# library untuk manipulasi data
import pandas as pd

# library untuk operasi numerik, array, multidimensi, dan fungsi matematika
import numpy as np 

# library untuk visualisasi data statistik
import seaborn as sns

# library untuk membuat grafik dan visualisasi data
import matplotlib.pyplot as plt
# Out:
# Matplotlib created a temporary cache directory at C:\Users\ILHAMX~1\AppData\Local\Temp\matplotlib-3g5f5bvq because the default path (C:\Users\ilham x dimas\.matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.

# %%
# melakukan pembacaan dataset dengan format csv
# menggungakan path directory masing - masing
data = pd.read_csv('C:\\Users\\ilham x dimas\\Downloads\\Pokemon.csv')
data
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# untuk mengetahui infomarsi dari data
data.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
# untuk mengetahui terdapat kolom apa saja dalam dataset
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# untuk mengetahui index yang terdapat pada dataset
data.index
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %%
# untuk mengetahui jumlah baris dan juga kolom pada dataset
data.shape
# Out:
# (800, 13)

# %%
# untuk mengetahui data statistik dari dataset
data.describe()
# Out:
#                 #      Total          HP      Attack     Defense     Sp. Atk  \
# count  800.000000  800.00000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750  435.10250   69.258750   79.001250   73.842500   72.820000
# std    208.343798  119.96304   25.534669   32.457366   31.183501   32.722294
# min      1.000000  180.00000    1.000000    5.000000    5.000000   10.000000
# 25%    184.750000  330.00000   50.000000   55.000000   50.000000   49.750000
# 50%    364.500000  450.00000   65.000000   75.000000   70.000000   65.000000
# 75%    539.250000  515.00000   80.000000  100.000000   90.000000   95.000000
# max    721.000000  780.00000  255.000000  190.000000  230.000000  194.000000
#
#           Sp. Def       Speed  Generation
# count  800.000000  800.000000   800.00000
# mean    71.902500   68.277500     3.32375
# std     27.828916   29.060474     1.66129
# min     20.000000    5.000000     1.00000
# 25%     50.000000   45.000000     2.00000
# ...

# %%
# Cleaning Data

# menghapus kolom indeks ke 0 dengan nama kolom '#'
# (Karena terjadi double id pada auto increment dan kolom '#' dari penampilan data)
data = data.drop(data.columns[0], axis = 1)
data
# Out:
#                       Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0                Bulbasaur    Grass  Poison    318  45      49       49
# 1                  Ivysaur    Grass  Poison    405  60      62       63
# 2                 Venusaur    Grass  Poison    525  80      82       83
# 3    VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4               Charmander     Fire     NaN    309  39      52       43
# ..                     ...      ...     ...    ...  ..     ...      ...
# 795                Diancie     Rock   Fairy    600  50     100      150
# 796    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799              Volcanion     Fire   Water    600  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
# untuk mengetahui informasi dataset setelah pembersihan
data.info ()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        800 non-null    object
#  1   Type 1      800 non-null    object
#  2   Type 2      414 non-null    object
#  3   Total       800 non-null    int64
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(8), object(3)
# memory usage: 69.7+ KB

# %%
# setelah pembersihan
data.columns
# Out:
# Index(['Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %%
# tidak ada perubahan setelah pembersihan
data.index
# Out:
# RangeIndex(start=0, stop=800, step=1)

# %%
# setelah pembersihan
data.shape
# Out:
# (800, 12)

# %%
# setelah pembersihan dataset
data.describe()
# Out:
#            Total          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.00000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   435.10250   69.258750   79.001250   73.842500   72.820000   71.902500
# std    119.96304   25.534669   32.457366   31.183501   32.722294   27.828916
# min    180.00000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    330.00000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    450.00000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    515.00000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    780.00000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %%
# menambahkan kolom untuk menghitung jumlah tipe 
data['Type Count'] = data.apply(lambda row: 1 if pd.isna(row['Type 2']) else 2, axis=1)

# menghitung jumlah Pokemon berdasarkan jumlah tipe 
type_counts = data['Type Count'].value_counts()

# menampilkan hasil
print("Jumlah Pokemon dengan 1 tipe:", type_counts.get(1, 0))
print("Jumlah Pokemon dengan 2 tipe:", type_counts.get(2, 0))

# membuat pie chart
plt.figure(figsize=(8, 6))
plt.pie(type_counts, autopct='%1.1f%%', startangle=140, colors=['#ff9999','#66b3ff'])

# Menambahkan keterangan
plt.legend(labels=['2 Tipe', '1 Tipe'], title='Jumlah Tipe', loc='upper left', bbox_to_anchor=(1, 1))

plt.title('Persentase Pokemon Berdasarkan Jumlah Tipe')
plt.axis('equal')
plt.show()
# Out:
# Jumlah Pokemon dengan 1 tipe: 386
# Jumlah Pokemon dengan 2 tipe: 414

# %%
# menghitung jumlah Pokemon untuk setiap tipe elemen di kolom 'Type 1'
type1_counts = data['Type 1'].value_counts()

# mengambil 5 tipe elemen teratas
top_5_types = type1_counts.head(5)

# menampilkan hasil
print("Top 5 Tipe Elemen di 'Type 1':")
print(top_5_types)

# membuat bar chart untuk top 5 tipe elemen
plt.figure(figsize=(10, 6))
top_5_types.plot(kind='bar', color='skyblue')
plt.title('Top 5 Tipe Elemen Pokemon Pada Tipe 1')
plt.xlabel('Tipe Elemen')
plt.ylabel('Jumlah Pokemon')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Top 5 Tipe Elemen di 'Type 1':
# Type 1
# Water      112
# Normal      98
# Grass       70
# Bug         69
# Psychic     57
# Name: count, dtype: int64

# %%
# menghitung jumlah Pokemon untuk setiap tipe elemen di kolom 'Type 1'
type1_counts = data['Type 2'].value_counts()

# mengambil 5 tipe elemen teratas
top_5_types = type1_counts.head(5)

# menampilkan hasil
print("Top 5 Tipe Elemen di 'Type 2':")
print(top_5_types)

# membuat bar chart untuk top 5 tipe elemen
plt.figure(figsize=(10, 6))
top_5_types.plot(kind='bar', color='skyblue')
plt.title('Top 5 Tipe Elemen Pokemon Pada Tipe 2')
plt.xlabel('Tipe Elemen')
plt.ylabel('Jumlah Pokemon')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()
# Out:
# Top 5 Tipe Elemen di 'Type 2':
# Type 2
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Name: count, dtype: int64

# %%
# menghitung jumlah Pokémon untuk setiap generasi
generation_counts = data['Generation'].value_counts()

# menampilkan jumlah Pokémon per generasi
print("Jumlah Pokemon per Generasi:")
print(generation_counts)

# membuat pie chart
plt.figure(figsize=(8, 8))
colors = plt.get_cmap('Set2').colors
plt.pie(generation_counts, autopct='%1.1f%%', startangle=140, colors=colors)

# menambahkan keterangan 
plt.legend(generation_counts.index, title='Generasi', loc='best', bbox_to_anchor=(1, 1))

plt.title('Persentase Pokemon Berdasarkan Generasi')
plt.axis('equal')
plt.show()
# Out:
# Jumlah Pokemon per Generasi:
# Generation
# 1    166
# 5    165
# 3    160
# 4    121
# 2    106
# 6     82
# Name: count, dtype: int64

# %%
# menghitung jumlah Pokémon Legendary dan Non-Legendary
legendary_counts = data['Legendary'].value_counts()

# menampilkan jumlah Pokémon berdasarkan kategori Legendary
print("Jumlah Pokemon Legendary:")
print(f"Legendary: {legendary_counts.get(True, 0)}")
print(f"Non-Legendary: {legendary_counts.get(False, 0)}")

# membuat pie chart
plt.figure(figsize=(8, 6))
colors = ['#ff9999', '#66b3ff']
plt.pie(legendary_counts, labels=['Non-Legendary', 'Legendary'], autopct='%1.1f%%', startangle=140, colors=colors)

# menambahkan keterangan
plt.legend(labels=['Non-Legendary', 'Legendary'], title='Status Legendary', loc='upper left', bbox_to_anchor=(1, 1))

plt.title('Persentase Pokomon Berdasarkan Status Legendary')
plt.axis('equal')  
plt.show()
# Out:
# Jumlah Pokemon Legendary:
# Legendary: 65
# Non-Legendary: 735

# %%
# mencari Pokemon dengan HP tertinggi
max_hp_value = data['HP'].max()

# menggunakan .loc untuk memilih baris dengan HP tertinggi
pokemon = data.loc[data['HP'] == max_hp_value]

# menampilkan informasi Pokemon dengan HP tertinggi 
print("Informasi Pokemon dengan HP tertinggi:")
print(pokemon.T)
# Out:
# Informasi Pokemon dengan HP tertinggi:
#                 261
# Name        Blissey
# Type 1       Normal
# Type 2          NaN
# Total           540
# HP              255
# Attack           10
# Defense          10
# Sp. Atk          75
# Sp. Def         135
# Speed            55
# Generation        2
# Legendary     False
# Type Count        1

# %%
# mencari Pokemon dengan Attack tertinggi
max_att_value = data['Attack'].max()

# menggunakan .loc untuk memilih baris dengan Attack tertinggi
pokemon = data.loc[data['Attack'] == max_att_value]

# menampilkan informasi Pokemon dengan Attack tertinggi 
print("Informasi Pokemon dengan Attack tertinggi:")
print(pokemon.T)
# Out:
# Informasi Pokemon dengan Attack tertinggi:
#                             163
# Name        MewtwoMega Mewtwo X
# Type 1                  Psychic
# Type 2                 Fighting
# Total                       780
# HP                          106
# Attack                      190
# Defense                     100
# Sp. Atk                     154
# Sp. Def                     100
# Speed                       130
# Generation                    1
# Legendary                  True
# Type Count                    2

# %%
# mencari Pokemon dengan Defense tertinggi
max_def_value = data['Defense'].max()

# menggunakan .loc untuk memilih baris dengan def tertinggi
pokemon = data.loc[data['Defense'] == max_def_value]

# menampilkan informasi Pokemon dengan Attack tertinggi 
print("Informasi Pokemon dengan Defense tertinggi:")
print(pokemon.T)
# Out:
# Informasi Pokemon dengan Defense tertinggi:
#                             224      230                333
# Name        SteelixMega Steelix  Shuckle  AggronMega Aggron
# Type 1                    Steel      Bug              Steel
# Type 2                   Ground     Rock                NaN
# Total                       610      505                630
# HP                           75       20                 70
# Attack                      125       10                140
# Defense                     230      230                230
# Sp. Atk                      55       10                 60
# Sp. Def                      95      230                 80
# Speed                        30        5                 50
# Generation                    2        2                  3
# Legendary                 False    False              False
# Type Count                    2        2                  1

# %%
# mencari Pokemon dengan Sp. Attack tertinggi
max_spatt_value = data['Sp. Atk'].max()

# menggunakan .loc untuk memilih baris dengan def tertinggi
pokemon = data.loc[data['Sp. Atk'] == max_spatt_value]

# menampilkan informasi Pokemon dengan Sp. Attack tertinggi
print("Informasi Pokemon dengan Sp. Attack tertinggi:")
print(pokemon.T)
# Out:
# Informasi Pokemon dengan Sp. Attack tertinggi:
#                             164
# Name        MewtwoMega Mewtwo Y
# Type 1                  Psychic
# Type 2                      NaN
# Total                       780
# HP                          106
# Attack                      150
# Defense                      70
# Sp. Atk                     194
# Sp. Def                     120
# Speed                       140
# Generation                    1
# Legendary                  True
# Type Count                    1

# %%
# mencari Pokemon dengan Sp. Defense tertinggi
max_spdef_value = data['Sp. Def'].max()

# menggunakan .loc untuk memilih baris dengan Sp. Defense tertinggi
pokemon = data.loc[data['Sp. Def'] == max_spdef_value]

# menampilkan informasi Pokemon dengan Sp. Defense tertinggi
print("Informasi Pokemon dengan Sp. Defense tertinggi:")
print(pokemon.T)
# Out:
# Informasi Pokemon dengan Sp. Defense tertinggi:
#                 230
# Name        Shuckle
# Type 1          Bug
# Type 2         Rock
# Total           505
# HP               20
# Attack           10
# Defense         230
# Sp. Atk          10
# Sp. Def         230
# Speed             5
# Generation        2
# Legendary     False
# Type Count        2

# %%
# mencari Pokemon dengan Speed tertinggi
max_Speed_value = data['Speed'].max()

# menggunakan .loc untuk memilih baris dengan Total tertinggi
pokemon = data.loc[data['Speed'] == max_Speed_value]

# menampilkan informasi Pokemon dengan Speed tertinggi
print("Informasi Pokemon dengan Speed tertinggi:")
print(pokemon.T)
# Out:
# Informasi Pokemon dengan Speed tertinggi:
#                           431
# Name        DeoxysSpeed Forme
# Type 1                Psychic
# Type 2                    NaN
# Total                     600
# HP                         50
# Attack                     95
# Defense                    90
# Sp. Atk                    95
# Sp. Def                    90
# Speed                     180
# Generation                  3
# Legendary                True
# Type Count                  1

# %%
# mencari Pokemon dengan Total tertinggi
max_Total_value = data['Total'].max()

# menggunakan .loc untuk memilih baris dengan Total tertinggi
pokemon = data.loc[data['Total'] == max_Total_value]

# menampilkan informasi Pokemon dengan Total tertinggi
print("Informasi Pokemon dengan Total tertinggi:")
print(pokemon.T)
# Out:
# Informasi Pokemon dengan Total tertinggi:
#                             163                  164                    426
# Name        MewtwoMega Mewtwo X  MewtwoMega Mewtwo Y  RayquazaMega Rayquaza
# Type 1                  Psychic              Psychic                 Dragon
# Type 2                 Fighting                  NaN                 Flying
# Total                       780                  780                    780
# HP                          106                  106                    105
# Attack                      190                  150                    180
# Defense                     100                   70                    100
# Sp. Atk                     154                  194                    180
# Sp. Def                     100                  120                    100
# Speed                       130                  140                    115
# Generation                    1                    1                      3
# ...
